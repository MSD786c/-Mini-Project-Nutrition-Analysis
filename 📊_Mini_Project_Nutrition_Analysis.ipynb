# %%
import pandas as pd

df = pd.read_csv("/content/FOOD-DATA-GROUP1.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %% [markdown]
# # **Cleaning the Data Set**
# - Drop unnecessary columns: Unnamed: 0, Unnamed: 0.1.
#
# - Standardize text: clean up food names (.str.strip().str title()).
#
# - Check for duplicates and drop them.
#
# - Ensure all numeric columns are properly typed (float/int).

# %%
df.describe()
# Out:
#        Caloric Value         Fat  Saturated Fats  Monounsaturated Fats  \
# count     551.000000  551.000000      551.000000            551.000000
# mean      237.359347   10.766933        3.722715              4.001564
# std       199.235598   12.544196        5.397021              5.540608
# min         3.000000    0.000000        0.000000              0.000000
# 25%        94.500000    2.500000        0.500000              0.600000
# 50%       186.000000    6.600000        1.800000              2.200000
# 75%       337.000000   14.400000        4.800000              5.150000
# max      1578.000000   87.500000       43.500000             48.000000
#
#        Polyunsaturated Fats  Carbohydrates      Sugars     Protein  \
# count            551.000000     551.000000  551.000000  551.000000
# mean               2.170793      15.819036    2.708907   18.417857
# std                3.470820      20.289320    7.455666   18.932404
# ...

# %%
print("Average Calories:", df["Caloric Value"].mean())
print("Median Calories:", df["Caloric Value"].median())
print("Lowest Calories:", df["Caloric Value"].min())
print("Highest Calories:", df["Caloric Value"].max())
# Out:
# Average Calories: 237.35934664246824
# Median Calories: 186.0
# Lowest Calories: 3
# Highest Calories: 1578

# %%
# Top 10 highest-calorie foods
print(df.nlargest(10, "Caloric Value")[["food", "Caloric Value"]])
# Out:
#                                        food  Caloric Value
# 153                    General Tsos Chicken           1578
# 83                            Lemon Chicken           1440
# 317  Double Whopper With Cheese Burger King           1061
# 17                           Gjetost Cheese           1058
# 306                        Double Hamburger            942
# 333              Double Whopper Burger King            942
# 319                 Sandwich With Cold Cuts            833
# 417                              Salmon Raw            824
# 330                     Whopper Burger King            790
# 66                         Kung Pao Chicken            779

# %%
# Top 10 lowest-calorie foods
print(df.nsmallest(10, "Caloric Value")[["food", "Caloric Value"]])
# Out:
#                       food  Caloric Value
# 422        Chum Salmon Raw              3
# 477           Crayfish Raw              3
# 527             Shrimp Raw              4
# 508          Shrimp Cooked              7
# 245      Beef Broth Powder              8
# 494  Anchovy Canned In Oil              8
# 518  Eastern Oyster Cooked              8
# 543     Eastern Oyster Raw              8
# 186      Chicken Broth Dry             10
# 532            Scallop Raw             10

# %%
# Top 10 lowest-protein foods
print(df.nsmallest(10, "Protein")[["food", "Protein"]])
# Out:
#                                       food  Protein
# 42                               Fruit Jam    0.000
# 133  Savoury Noodle One Pan Dinner Tandaco    0.000
# 255              Little India Little Lunch    0.000
# 256  Original Chicken Sandwich Chick Fil A    0.000
# 269            Egg White Delight Mcdonalds    0.000
# 321  Hand Breaded Chicken Tenders Carls Jr    0.000
# 322        Grilled Chicken Sandwich Wendys    0.000
# 504                Wild Pink Salmon Oceans    0.000
# 49                        Orange Marmalade    0.014
# 41                            Apple Butter    0.045

# %%
# Top 10 highest-protein foods
print(df.nlargest(10, "Protein")[["food", "Protein"]])
# Out:
#                       food  Protein
# 361   Skipjack Tuna Cooked     86.9
# 456      Yellowtail Cooked     86.6
# 462         Yellowtail Raw     86.5
# 490     Sockeye Salmon Raw     84.4
# 413  Sockeye Salmon Cooked     82.1
# 417             Salmon Raw     80.9
# 499     Pink Salmon Canned     80.9
# 363     Chum Salmon Cooked     79.5
# 497  Sockeye Salmon Canned     79.5
# 420  Chinook Salmon Cooked     79.2

# %%
# Protein density (protein per calorie)
df["Protein Density"] = df["Protein"] / df["Caloric Value"]

# Fiber density
df["Fiber Density"] = df["Dietary Fiber"] / df["Caloric Value"]

# Sugar ratio
df["Sugar Ratio"] = df["Sugars"] / (df["Carbohydrates"] + 1e-5)  # avoid division by 0

# %%
# Top 10 foods by protein density
print(df.nlargest(10, "Protein Density")[["food", "Protein Density", "Caloric Value","Protein"]])
# Out:
#                             food  Protein Density  Caloric Value  Protein
# 37    Mozzarella Cheese Fat Free         0.225157            159     35.8
# 469           Yellowfin Tuna Raw         0.222581             31      6.9
# 346               Haddock Cooked         0.222222            135     30.0
# 457        Yellowfin Tuna Cooked         0.221622             37      8.2
# 379                  Haddock Raw         0.220280            143     31.5
# 345            Northern Pike Raw         0.219253            348     76.3
# 394  Pumpkin Seed Sunfish Cooked         0.219048             42      9.2
# 458                  Ling Cooked         0.219048            168     36.8
# 440                     Cusk Raw         0.218868            106     23.2
# 506         Alaska King Crab Raw         0.218750            144     31.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

sns.histplot(data=df, x='Caloric Value', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Caloric Value')

sns.histplot(data=df, x='Protein', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Protein')

sns.histplot(data=df, x='Fat', kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Fat')

sns.histplot(data=df, x='Carbohydrates', kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Distribution of Carbohydrates')

plt.tight_layout()
plt.show()

# %%
# Presentation of Distribution Plots

print("--- Distribution Plots ---")

# Display the distribution plots (assuming they are still in the notebook's output)
# If not, the code to generate them would be here again, but since they were
# successfully generated, we will focus on the insights based on the previous output.

print("\nInsights from Distribution Plots:")

print("\nDistribution of Caloric Value:")
print("- The distribution of Caloric Value is skewed to the right, indicating that most foods have lower caloric values, with fewer foods having very high caloric values.")
print("- The majority of foods fall within the range of 0 to approximately 400 calories.")
print("- There is a long tail extending towards higher caloric values, suggesting the presence of some high-calorie food items.")

print("\nDistribution of Protein:")
print("- The distribution of Protein is also skewed to the right, with a concentration of foods having lower protein content.")
print("- There is a noticeable peak at lower protein values, and the distribution gradually decreases as protein content increases.")
print("- Similar to caloric value, there are fewer foods with very high protein content.")

print("\nDistribution of Fat:")
print("- The distribution of Fat is skewed to the right as well.")
print("- Many foods have low fat content, and the frequency decreases as fat content increases.")
print("- The distribution shows a spread of fat values, with some foods containing significantly higher amounts of fat.")

print("\nDistribution of Carbohydrates:")
print("- The distribution of Carbohydrates is skewed to the right, with a large number of foods having low carbohydrate values.")
print("- There is a peak at the lower end of the carbohydrate range.")
print("- The distribution extends to higher carbohydrate values, but with decreasing frequency.")
# Out:
# --- Distribution Plots ---
#
# Insights from Distribution Plots:
#
# Distribution of Caloric Value:
# - The distribution of Caloric Value is skewed to the right, indicating that most foods have lower caloric values, with fewer foods having very high caloric values.
# - The majority of foods fall within the range of 0 to approximately 400 calories.
# - There is a long tail extending towards higher caloric values, suggesting the presence of some high-calorie food items.
#
# Distribution of Protein:
# - The distribution of Protein is also skewed to the right, with a concentration of foods having lower protein content.
# - There is a noticeable peak at lower protein values, and the distribution gradually decreases as protein content increases.
# - Similar to caloric value, there are fewer foods with very high protein content.
#
# Distribution of Fat:
# - The distribution of Fat is skewed to the right as well.
# ...

# %% [markdown]
# ## Boxplots
#
#
# food categories boxplots to visualize the distribution of Calories across these categories and identify outliers.

# %%
def categorize_food(food_name):
    food_name = food_name.lower()
    if 'cheese' in food_name or 'milk' in food_name or 'yogurt' in food_name:
        return 'Dairy'
    elif 'chicken' in food_name or 'beef' in food_name or 'pork' in food_name or 'lamb' in food_name:
        return 'Meat'
    elif 'salmon' in food_name or 'tuna' in food_name or 'shrimp' in food_name or 'fish' in food_name:
        return 'Seafood'
    elif 'rice' in food_name or 'bread' in food_name or 'pasta' in food_name or 'oats' in food_name:
        return 'Grains'
    elif 'apple' in food_name or 'banana' in food_name or 'berry' in food_name or 'orange' in food_name:
        return 'Fruit'
    elif 'brocoli' in food_name or 'spinach' in food_name or 'carrot' in food_name or 'potato' in food_name:
        return 'Vegetable'
    elif 'nut' in food_name or 'seed' in food_name:
        return 'Nuts and Seeds'
    elif 'oil' in food_name or 'butter' in food_name or 'margarine' in food_name:
        return 'Fats and Oils'
    elif 'sauce' in food_name or 'dressing' in food_name or 'soup' in food_name:
        return 'Sauces and Soups'
    elif 'burger' in food_name or 'sandwich' in food_name or 'pizza' in food_name:
        return 'Fast Food'
    else:
        return 'Other'

df['food_category'] = df['food'].apply(categorize_food)

plt.figure(figsize=(15, 8))
sns.boxplot(x='food_category', y='Caloric Value', data=df)
plt.title("Distribution of Caloric Value Across Food Categories")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Presentation of Boxplot

print("\n--- Boxplot ---")

# Display the boxplot (assuming it is still in the notebook's output)
# If not, the code to generate it would be here again.

print("\nInsights from Boxplot:")
print("\nDistribution of Caloric Value Across Food Categories:")
print("- The boxplot reveals significant variation in the distribution of caloric values across different food categories.")
print("- 'Fast Food' and 'Meat' categories appear to have higher median caloric values and wider ranges compared to categories like 'Fruit' and 'Vegetable'.")
print("- Many categories show outliers with very high caloric values, indicating specific food items within those categories that are exceptionally calorie-dense.")
print("- Categories like 'Fruit' and 'Vegetable' generally have lower caloric values with fewer outliers.")
# Out:
# --- Boxplot ---
#
# Insights from Boxplot:
#
# Distribution of Caloric Value Across Food Categories:
# - The boxplot reveals significant variation in the distribution of caloric values across different food categories.
# - 'Fast Food' and 'Meat' categories appear to have higher median caloric values and wider ranges compared to categories like 'Fruit' and 'Vegetable'.
# - Many categories show outliers with very high caloric values, indicating specific food items within those categories that are exceptionally calorie-dense.
# - Categories like 'Fruit' and 'Vegetable' generally have lower caloric values with fewer outliers.

# %% [markdown]
# ## Scatterplots
#
#
# - Calories and Protein
# - Carbohydrates and Sugars
# - Calories and Nutrition Density

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.scatterplot(data=df, x='Protein', y='Caloric Value', ax=axes[0])
axes[0].set_title('Calories vs. Protein')
axes[0].set_xlabel('Protein')
axes[0].set_ylabel('Caloric Value')

sns.scatterplot(data=df, x='Sugars', y='Carbohydrates', ax=axes[1])
axes[1].set_title('Carbohydrates vs. Sugars')
axes[1].set_xlabel('Sugars')
axes[1].set_ylabel('Carbohydrates')

sns.scatterplot(data=df, x='Nutrition Density', y='Caloric Value', ax=axes[2])
axes[2].set_title('Calories vs. Nutrition Density')
axes[2].set_xlabel('Nutrition Density')
axes[2].set_ylabel('Caloric Value')

plt.tight_layout()
plt.show()

# Presentation of Scatterplots

print("\n--- Scatterplots ---")

# Display the scatterplots (assuming they are still in the notebook's output)
# If not, the code to generate them would be here again.

print("\nInsights from Scatterplots:")

print("\nCalories vs. Protein:")
print("- There appears to be a generally positive correlation between Caloric Value and Protein, meaning foods with higher protein content tend to have higher caloric values.")
print("- However, the relationship is not perfectly linear, and there is a spread of data points, indicating that other factors also contribute to caloric value.")
print("- Some outliers with high caloric values do not necessarily have proportionally high protein, and vice versa.")

print("\nCarbohydrates vs. Sugars:")
print("- There is a strong positive correlation between Carbohydrates and Sugars, which is expected as sugars are a type of carbohydrate.")
print("- Foods with higher carbohydrate content generally have higher sugar content.")
print("- The scatterplot shows a clear linear trend, with some deviation, suggesting that not all carbohydrates are sugars.")

print("\nCalories vs. Nutrition Density:")
print("- There is a positive correlation between Caloric Value and Nutrition Density.")
print("- Foods with higher caloric values tend to have higher nutrition density values.")
print("- It's important to note that 'Nutrition Density' as calculated here is simply the sum of nutrient percentages, so this relationship is somewhat definitional.")
print("- Outliers with high caloric values also tend to have high nutrition density, but there are also foods with lower calories that have relatively high nutrition density.")
# Out:
# --- Scatterplots ---
#
# Insights from Scatterplots:
#
# Calories vs. Protein:
# - There appears to be a generally positive correlation between Caloric Value and Protein, meaning foods with higher protein content tend to have higher caloric values.
# - However, the relationship is not perfectly linear, and there is a spread of data points, indicating that other factors also contribute to caloric value.
# - Some outliers with high caloric values do not necessarily have proportionally high protein, and vice versa.
#
# Carbohydrates vs. Sugars:
# - There is a strong positive correlation between Carbohydrates and Sugars, which is expected as sugars are a type of carbohydrate.
# - Foods with higher carbohydrate content generally have higher sugar content.
# - The scatterplot shows a clear linear trend, with some deviation, suggesting that not all carbohydrates are sugars.
#
# Calories vs. Nutrition Density:
# - There is a positive correlation between Caloric Value and Nutrition Density.
# ...

# %% [markdown]
# ## Heatmap
#
#
# Calculate the correlation matrix between numerical nutrient columns and visualize it using a heatmap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Identify numerical columns in the dataframe
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()

# Define a list of potential nutrient columns (excluding calculated ones and identifiers)
potential_nutrient_cols = [
    'Caloric Value', 'Fat', 'Saturated Fats', 'Monounsaturated Fats',
    'Polyunsaturated Fats', 'Carbohydrates', 'Sugars', 'Protein',
    'Dietary Fiber', 'Cholesterol', 'Sodium', 'Calcium', 'Copper',
    'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium',
    'Selenium', 'Zinc', 'Vitamin A', 'Vitamin C', 'Vitamin D', 'Vitamin E',
    'Vitamin K', 'Thiamin', 'Riboflavin', 'Niacin', 'Pantothenic acid',
    'Vitamin B6', 'Folate', 'Vitamin B12'
]

# Filter the potential nutrient columns to include only those present in the dataframe and are numerical
nutrient_cols_present = [col for col in potential_nutrient_cols if col in numerical_cols]

# Calculate the correlation matrix for the selected numerical nutrient columns
correlation_matrix = df[nutrient_cols_present].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title("Correlation Matrix of Nutrients")
plt.show()

# Presentation of Heatmap

print("\n--- Heatmap ---")

# Display the heatmap (assuming it is still in the notebook's output)
# If not, the code to generate it would be here again.

print("\nInsights from Heatmap:")
print("\nCorrelation Matrix of Nutrients:")
print("- The heatmap visually represents the correlations between different numerical nutrient columns.")
print("- Darker shades of red indicate strong positive correlations, while darker shades of blue indicate strong negative correlations.")
print("- Light shades or white indicate weak correlations.")
print("- Notable strong positive correlations exist between:")
print("  - Caloric Value and Fat")
print("  - Fat and Saturated Fats, Monounsaturated Fats, and Polyunsaturated Fats")
print("  - Carbohydrates and Sugars")
print("  - Protein and various vitamins and minerals (e.g., Vitamin B6, Potassium, Phosphorus)")
print("- Some nutrients show weak or negligible correlations with many others, suggesting they are not strongly related in this dataset.")
print("- The diagonal line represents the correlation of a nutrient with itself, which is always 1.")
# Out:
# --- Heatmap ---
#
# Insights from Heatmap:
#
# Correlation Matrix of Nutrients:
# - The heatmap visually represents the correlations between different numerical nutrient columns.
# - Darker shades of red indicate strong positive correlations, while darker shades of blue indicate strong negative correlations.
# - Light shades or white indicate weak correlations.
# - Notable strong positive correlations exist between:
#   - Caloric Value and Fat
#   - Fat and Saturated Fats, Monounsaturated Fats, and Polyunsaturated Fats
#   - Carbohydrates and Sugars
#   - Protein and various vitamins and minerals (e.g., Vitamin B6, Potassium, Phosphorus)
# - Some nutrients show weak or negligible correlations with many others, suggesting they are not strongly related in this dataset.
# - The diagonal line represents the correlation of a nutrient with itself, which is always 1.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort by Protein Density and get top/bottom 10
df_sorted_protein_density = df.sort_values(by='Protein Density', ascending=False)
top_10_protein_density = df_sorted_protein_density.head(10)
bottom_10_protein_density = df_sorted_protein_density.tail(10)

# Combine for plotting
protein_density_plot_data = pd.concat([top_10_protein_density, bottom_10_protein_density])

# Create the bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='food', y='Protein Density', data=protein_density_plot_data)
plt.title('Top 10 Highest and Lowest Protein Density Foods')
plt.xlabel('Food')
plt.ylabel('Protein Density (Protein per Calorie)')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Protein Density Bar Plot
#
# This bar plot displays the foods with the highest and lowest protein density. Protein density is calculated as the amount of protein per calorie. Foods with a higher protein density provide more protein relative to their caloric value.
#
# **Insights:**
#
# *   The plot highlights foods that are very protein-rich for their caloric content, which can be useful for those looking to maximize protein intake without excessive calories.
# *   Conversely, it shows foods with very low protein density, indicating they provide relatively few grams of protein per calorie.
# *   Examining the food names helps identify specific items that are either excellent or poor sources of protein when considering caloric intake.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The distributions of Caloric Value, Protein, Fat, and Carbohydrates are all skewed to the right, with most food items having lower values for these nutrients.
# *   The distribution of Caloric Value varies significantly across food categories, with "Fast Food" and "Meat" categories showing higher median caloric values and more outliers compared to "Fruit" and "Vegetable" categories.
# *   There is a generally positive correlation between Caloric Value and Protein, and a strong positive correlation between Carbohydrates and Sugars.
# *   Foods with higher caloric values tend to have higher nutrition density values (based on the calculated metric).
# *   The heatmap of nutrient correlations shows strong positive correlations between Caloric Value and Fat, different types of fats, and Carbohydrates and Sugars. Protein shows positive correlations with various vitamins and minerals.
#
# ### Insights or Next Steps
#
# *   The presence of outliers in the boxplots and scatterplots suggests the need for further investigation into these specific food items to understand their nutritional profiles better.
# *   The strong correlations observed in the heatmap can inform potential strategies for grouping or analyzing nutrients together in future steps, such as identifying food groups high in specific nutrient combinations.
